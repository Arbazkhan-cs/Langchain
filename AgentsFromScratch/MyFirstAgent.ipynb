# %% [markdown]
# ## Importing Neccessary Libraries

# %%
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate
from langchain.agents import create_tool_calling_agent, tool, AgentExecutor

from dotenv import load_dotenv
import re
from importlib import import_module
import subprocess
import sys
import tempfile
import os

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Load Model

# %%
# Template for the system and user messages
template = ChatPromptTemplate.from_messages([
    ("system", """You are a Python code generator and tester. Respond only with executable Python code. Follow these steps:
     1). If any libraries need to be installed, use the install_libraries function first. For example: install_libraries("python-pptx")
     2). Generate the Python code to complete the task.
     3). If there is any error, regenerate the code after fixing issue and repeat the steps.
     4). If the code runs successfully without errors, respond with the final code and the message "TASK_COMPLETE".
     Do not include pip install commands in the code itself."""),
    ("user", "Generate Python code to {input} {agent_scratchpad}")
])

# Load the model
llm = ChatGroq(model="llama3-70b-8192", temperature=0.7)

# %% [markdown]
# ## Create Tools

# %%
@tool
def install_libraries(libraries: str) -> bool:
    """Install necessary libraries. Input should be a comma-separated string of library names."""
    libraries = [lib.strip() for lib in libraries.split(',')]
    installed = False
    for lib in libraries:
        try:
            import_module(lib.replace('-', '_'))
            print(f"{lib} is already installed.")
        except ImportError:
            print(f"Installing {lib}...")
            try:
                subprocess.check_call([sys.executable, "-m", "pip", "install", lib])
                installed = True
            except subprocess.CalledProcessError as e:
                print(f"Failed to install {lib}: {e}")
                return False
    return installed

@tool
def execute_code(code: str) -> tuple:
    """It will execute the code and return output and error."""
    with tempfile.NamedTemporaryFile(mode='w', suffix=".py", delete=False) as temp_file:
        temp_file.write(code)
        temp_file_path = temp_file.name
    try:
        result = subprocess.run([sys.executable, temp_file_path], capture_output=True, text=True, timeout=30)
        output = result.stdout
        err = result.stderr
    except subprocess.TimeoutExpired:
        output = ""
        err = "Execution timed out after 30 seconds."
    except Exception as e:
        output = ""
        err = f"An error occurred during execution: {str(e)}"
    finally:
        os.unlink(temp_file_path)
    return output, err

# %%
# Create tools list
tools = [install_libraries, execute_code]

# Create agent
agent = create_tool_calling_agent(
    llm=llm, 
    tools=tools, 
    prompt=template
)

# Create agent executor
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)

# %%
try:
    result = agent_executor.invoke({
        "input": """code for palindrome"""
    })
    print("Execution Result:", result)
    if "TASK_COMPLETE" in str(result):
        print("Task completed successfully.")
        exit  # Exit the loop or stop further execution
except Exception as e:
    print(f"An error occurred during agent execution: {str(e)}")
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `execute_code` with `{'code': 'def is_palindrome(s):\n    return s == s[::-1]\n\nprint(is_palindrome([]))'}`
#
#
# ('True\n', '')
# Invoking: `install_libraries` with `{'libraries': 'python'}`
#
#
# Installing python...
# Failed to install python: Command '['c:\\Users\\Arbaz Khan\\Desktop\\LangChain\\venv\\Scripts\\python.exe', '-m', 'pip', 'install', 'python']' returned non-zero exit status 1.
# False
# Invoking: `execute_code` with `{'code': "def is_palindrome(s):\n    return s == s[::-1]\n\nprint(is_palindrome('your_string_here'))"}`
#
#
# ('False\n', '')
# Invoking: `execute_code` with `{'code': "def is_palindrome(s):\n    return s == s[::-1]\n\nprint(is_palindrome('your_string_here'))"}`
#
#
# ('False\n', '')
# Invoking: `install_libraries` with `{'libraries': 'python'}`
#
#
# Installing python...
# Failed to install python: Command '['c:\\Users\\Arbaz Khan\\Desktop\\LangChain\\venv\\Scripts\\python.exe', '-m', 'pip', 'install', 'python']' returned non-zero exit status 1.
# False
# Invoking: `install_libraries` with `{'libraries': 'python'}`
#
#
# Installing python...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 8, in install_libraries(libraries)
#       7 try:
# ----> 8     import_module(lib.replace('-', '_'))
#       9     print(f"{lib} is already installed.")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'python'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 try:
# ----> 2     result = agent_executor.invoke({
#       3         "input": """code for palindrome"""
#       4     })
#       5     print("Execution Result:", result)
#       6     if "TASK_COMPLETE" in str(result):
#
# File c:\Users\Arbaz Khan\Desktop\LangChain\venv\Lib\site-packages\langchain\chains\base.py:164, in Chain.invoke(self, input, config, **kwargs)
#     162 except BaseException as e:
#     163     run_manager.on_chain_error(e)
# --> 164     raise e
#     165 run_manager.on_chain_end(outputs)
#     167 if include_run_info:
#
# File c:\Users\Arbaz Khan\Desktop\LangChain\venv\Lib\site-packages\langchain\chains\base.py:154, in Chain.invoke(self, input, config, **kwargs)
#     151 try:
#     152     self._validate_inputs(inputs)
#     153     outputs = (
# --> 154         self._call(inputs, run_manager=run_manager)
#     155         if new_arg_supported
#     156         else self._call(inputs)
#     157     )
#     159     final_outputs: Dict[str, Any] = self.prep_outputs(
#     160         inputs, outputs, return_only_outputs
#     161     )
#     162 except BaseException as e:
#
# File c:\Users\Arbaz Khan\Desktop\LangChain\venv\Lib\site-packages\langchain\agents\agent.py:1625, in AgentExecutor._call(self, inputs, run_manager)
#    1623 # We now enter the agent loop (until it returns something).
#    1624 while self._should_continue(iterations, time_elapsed):
# -> 1625     next_step_output = self._take_next_step(
#    1626         name_to_tool_map,
#    1627         color_mapping,
#    1628         inputs,
#    1629         intermediate_steps,
#    1630         run_manager=run_manager,
#    1631     )
#    1632     if isinstance(next_step_output, AgentFinish):
#    1633         return self._return(
#    1634             next_step_output, intermediate_steps, run_manager=run_manager
#    1635         )
#
# File c:\Users\Arbaz Khan\Desktop\LangChain\venv\Lib\site-packages\langchain\agents\agent.py:1331, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1322 def _take_next_step(
#    1323     self,
#    1324     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1328     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1329 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1330     return self._consume_next_step(
# -> 1331         [
#    1332             a
#    1333             for a in self._iter_next_step(
#    1334                 name_to_tool_map,
#    1335                 color_mapping,
#    1336                 inputs,
#    1337                 intermediate_steps,
#    1338                 run_manager,
#    1339             )
#    1340         ]
#    1341     )
#
# File c:\Users\Arbaz Khan\Desktop\LangChain\venv\Lib\site-packages\langchain\agents\agent.py:1331, in <listcomp>(.0)
#    1322 def _take_next_step(
#    1323     self,
#    1324     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1328     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1329 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1330     return self._consume_next_step(
# -> 1331         [
#    1332             a
#    1333             for a in self._iter_next_step(
#    1334                 name_to_tool_map,
#    1335                 color_mapping,
#    1336                 inputs,
#    1337                 intermediate_steps,
#    1338                 run_manager,
#    1339             )
#    1340         ]
#    1341     )
#
# File c:\Users\Arbaz Khan\Desktop\LangChain\venv\Lib\site-packages\langchain\agents\agent.py:1416, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1414     yield agent_action
#    1415 for agent_action in actions:
# -> 1416     yield self._perform_agent_action(
#    1417         name_to_tool_map, color_mapping, agent_action, run_manager
#    1418     )
#
# File c:\Users\Arbaz Khan\Desktop\LangChain\venv\Lib\site-packages\langchain\agents\agent.py:1438, in AgentExecutor._perform_agent_action(self, name_to_tool_map, color_mapping, agent_action, run_manager)
#    1436         tool_run_kwargs["llm_prefix"] = ""
#    1437     # We then call the tool on the tool input to get an observation
# -> 1438     observation = tool.run(
#    1439         agent_action.tool_input,
#    1440         verbose=self.verbose,
#    1441         color=color,
#    1442         callbacks=run_manager.get_child() if run_manager else None,
#    1443         **tool_run_kwargs,
#    1444     )
#    1445 else:
#    1446     tool_run_kwargs = self._action_agent.tool_run_logging_kwargs()
#
# File c:\Users\Arbaz Khan\Desktop\LangChain\venv\Lib\site-packages\langchain_core\tools\base.py:586, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     584 if error_to_raise:
#     585     run_manager.on_tool_error(error_to_raise)
# --> 586     raise error_to_raise
#     587 output = _format_output(content, artifact, tool_call_id, self.name, status)
#     588 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File c:\Users\Arbaz Khan\Desktop\LangChain\venv\Lib\site-packages\langchain_core\tools\base.py:555, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     553 if config_param := _get_runnable_config_param(self._run):
#     554     tool_kwargs[config_param] = config
# --> 555 response = context.run(self._run, *tool_args, **tool_kwargs)
#     556 if self.response_format == "content_and_artifact":
#     557     if not isinstance(response, tuple) or len(response) != 2:
#
# File c:\Users\Arbaz Khan\Desktop\LangChain\venv\Lib\site-packages\langchain_core\tools\structured.py:69, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      67     if config_param := _get_runnable_config_param(self.func):
#      68         kwargs[config_param] = config
# ---> 69     return self.func(*args, **kwargs)
#      70 raise NotImplementedError("StructuredTool does not support sync invocation.")
#
# Cell In[12], line 13, in install_libraries(libraries)
#      11 print(f"Installing {lib}...")
#      12 try:
# ---> 13     subprocess.check_call([sys.executable, "-m", "pip", "install", lib])
#      14     installed = True
#      15 except subprocess.CalledProcessError as e:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:408, in check_call(*popenargs, **kwargs)
#     398 def check_call(*popenargs, **kwargs):
#     399     """Run command with arguments.  Wait for command to complete.  If
#     400     the exit code was zero then return, otherwise raise
#     401     CalledProcessError.  The CalledProcessError object will have the
#    (...)
#     406     check_call(["ls", "-l"])
#     407     """
# --> 408     retcode = call(*popenargs, **kwargs)
#     409     if retcode:
#     410         cmd = kwargs.get("args")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:391, in call(timeout, *popenargs, **kwargs)
#     389 with Popen(*popenargs, **kwargs) as p:
#     390     try:
# --> 391         return p.wait(timeout=timeout)
#     392     except:  # Including KeyboardInterrupt, wait handled that.
#     393         p.kill()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:1590, in Popen._wait(self, timeout)
#    1587     timeout_millis = int(timeout * 1000)
#    1588 if self.returncode is None:
#    1589     # API note: Returns immediately if timeout_millis == 0.
# -> 1590     result = _winapi.WaitForSingleObject(self._handle,
#    1591                                          timeout_millis)
#    1592     if result == _winapi.WAIT_TIMEOUT:
#    1593         raise TimeoutExpired(self.args, timeout)
#
# KeyboardInterrupt:

# %%
print(result["output"].split("```")[1])
# Out:
# # No pip installation required
#
# def is_palindrome(s):
#     return s == s[::-1]
#
# print(is_palindrome('your_string'))
# TASK_COMPLETE

# %%
# Out:
# False
